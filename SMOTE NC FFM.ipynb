# %%
import math
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('C:/Users/HCJ/Desktop/2021_Summer/Finance_data/bank.csv')
train_data, test_data = train_test_split(data,test_size=0.2, random_state=100)
print(train_data.shape)
print(test_data.shape)
# Out:
# (95628, 94)
# (23907, 94)

# %%
X_train = train_data.iloc[:,2:]
y_train = train_data['TARGET']
X_test = test_data.iloc[:,2:]
y_test = test_data['TARGET']

# %%
smotenc = SMOTENC(categorical_features = [42,43,44,63,64,65,66,67])
X_train_samp, y_train_samp = smotenc.fit_resample(X_train,y_train)

# %%
X_train_samp.head()
# Out:
#    J_F1_LON_RK_3M_CNT_RE  J_F1_OTHER_LON_6M_AVBL_AM_RE  \
# 0                      1                             2
# 1                      1                             1
# 2                      3                             3
# 3                      2                             3
# 4                      3                             3
#
#    J_F1_OTHER_LON_MAX_3M_AM_RE  J_SHINBO_GIBO_AM_RE  J_TOT_LON_CNT_RE  \
# 0                            3                    1                 3
# 1                            2                    1                 1
# 2                            3                    1                 1
# 3                            3                    1                 1
# 4                            4                    2                 1
#
#    J_TOT_LON_AGG_AM_RE  J_TOT_LON_MAX_AM_RE  J_DPS_CT_BAL_AM_RE  \
# 0                    3                    3                   2
# 1                    1                    1                   1
# 2                    1                    1                   1
# 3                    1                    1                   2
# 4                    1                    1                   1
#
#    J_TOT_DPS_1M_AVBL_AM_RE  J_TOT_DPS_6M_AVBL_AM_RE  ...  P_BR_CNTC_1M_CNT_RE  \
# 0                        2                        3  ...                    1
# 1                        1                        1  ...                    1
# 2                        1                        1  ...                    1
# 3                        2                        2  ...                    1
# 4                        1                        1  ...                    1
#
#    P_BR_CNTC_6M_CNT_RE  P_ATM_CNTC_6M_CNT_RE  P_INT_CNTC_6M_CNT_RE  \
# 0                    1                     1                     1
# 1                    1                     1                     1
# 2                    1                     3                     2
# 3                    1                     1                     2
# 4                    1                     1                     1
#
#    P_TOT_LON_CNT_RE  P_TOT_LON_AGG_AM_RE  P_TOT_TS_6M_CNT_RE  \
# 0                 1                    1                   1
# 1                 1                    1                   1
# 2                 3                    3                   3
# 3                 1                    1                   1
# 4                 1                    1                   1
#
#    P_TOT_TS_6M_AM_RE  P_OB_TS_6M_CNT_RE  P_OB_TS_6M_AM_RE
# 0                  1                  1                 1
# 1                  1                  1                 1
# 2                  3                  3                 3
# 3                  1                  1                 1
# 4                  1                  1                 1
#
# [5 rows x 92 columns]

# %%
y_train_samp.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: TARGET, dtype: int64

# %%
train = pd.concat([y_train_samp,X_train_samp],axis=1)
test = pd.concat([y_test,X_test],axis=1)

# %%
train.head()
# Out:
#    TARGET  J_F1_LON_RK_3M_CNT_RE  J_F1_OTHER_LON_6M_AVBL_AM_RE  \
# 0       0                      1                             2
# 1       0                      1                             1
# 2       0                      3                             3
# 3       0                      2                             3
# 4       0                      3                             3
#
#    J_F1_OTHER_LON_MAX_3M_AM_RE  J_SHINBO_GIBO_AM_RE  J_TOT_LON_CNT_RE  \
# 0                            3                    1                 3
# 1                            2                    1                 1
# 2                            3                    1                 1
# 3                            3                    1                 1
# 4                            4                    2                 1
#
#    J_TOT_LON_AGG_AM_RE  J_TOT_LON_MAX_AM_RE  J_DPS_CT_BAL_AM_RE  \
# 0                    3                    3                   2
# 1                    1                    1                   1
# 2                    1                    1                   1
# 3                    1                    1                   2
# 4                    1                    1                   1
#
#    J_TOT_DPS_1M_AVBL_AM_RE  ...  P_BR_CNTC_1M_CNT_RE  P_BR_CNTC_6M_CNT_RE  \
# 0                        2  ...                    1                    1
# 1                        1  ...                    1                    1
# 2                        1  ...                    1                    1
# 3                        2  ...                    1                    1
# 4                        1  ...                    1                    1
#
#    P_ATM_CNTC_6M_CNT_RE  P_INT_CNTC_6M_CNT_RE  P_TOT_LON_CNT_RE  \
# 0                     1                     1                 1
# 1                     1                     1                 1
# 2                     3                     2                 3
# 3                     1                     2                 1
# 4                     1                     1                 1
#
#    P_TOT_LON_AGG_AM_RE  P_TOT_TS_6M_CNT_RE  P_TOT_TS_6M_AM_RE  \
# 0                    1                   1                  1
# 1                    1                   1                  1
# 2                    3                   3                  3
# 3                    1                   1                  1
# 4                    1                   1                  1
#
#    P_OB_TS_6M_CNT_RE  P_OB_TS_6M_AM_RE
# 0                  1                 1
# 1                  1                 1
# 2                  3                 3
# 3                  1                 1
# 4                  1                 1
#
# [5 rows x 93 columns]

# %%
test.head()
# Out:
#        TARGET  J_F1_LON_RK_3M_CNT_RE  J_F1_OTHER_LON_6M_AVBL_AM_RE  \
# 56753       0                      1                             2
# 76624       0                      3                             2
# 15025       0                      3                             3
# 21125       0                      3                             3
# 16334       0                      1                             1
#
#        J_F1_OTHER_LON_MAX_3M_AM_RE  J_SHINBO_GIBO_AM_RE  J_TOT_LON_CNT_RE  \
# 56753                            3                    1                 1
# 76624                            3                    2                 1
# 15025                            4                    2                 1
# 21125                            3                    1                 1
# 16334                            1                    1                 1
#
#        J_TOT_LON_AGG_AM_RE  J_TOT_LON_MAX_AM_RE  J_DPS_CT_BAL_AM_RE  \
# 56753                    1                    1                   1
# 76624                    1                    1                   3
# 15025                    1                    1                   1
# 21125                    1                    1                   1
# 16334                    1                    1                   1
#
#        J_TOT_DPS_1M_AVBL_AM_RE  ...  P_BR_CNTC_1M_CNT_RE  P_BR_CNTC_6M_CNT_RE  \
# 56753                        1  ...                    1                    2
# 76624                        3  ...                    2                    3
# 15025                        1  ...                    1                    1
# 21125                        1  ...                    1                    1
# 16334                        1  ...                    1                    1
#
#        P_ATM_CNTC_6M_CNT_RE  P_INT_CNTC_6M_CNT_RE  P_TOT_LON_CNT_RE  \
# 56753                     3                     1                 3
# 76624                     1                     2                 2
# 15025                     1                     1                 1
# 21125                     3                     2                 3
# 16334                     1                     1                 1
#
#        P_TOT_LON_AGG_AM_RE  P_TOT_TS_6M_CNT_RE  P_TOT_TS_6M_AM_RE  \
# 56753                    2                   3                  3
# 76624                    2                   1                  1
# 15025                    1                   1                  1
# 21125                    3                   3                  3
# 16334                    1                   1                  1
#
#        P_OB_TS_6M_CNT_RE  P_OB_TS_6M_AM_RE
# 56753                  3                 3
# 76624                  1                 1
# 15025                  1                 1
# 21125                  3                 3
# 16334                  1                 1
#
# [5 rows x 93 columns]

# %%
x = pd.concat([train,test])
x = x.reset_index(drop=True)
unwanted = x.columns[x.columns.str.startswith('ps_calc_')]
x.drop(unwanted,inplace=True,axis=1)

# %%
features = x.columns[2:]
categories = []
for c in features:
    trainno = len(x.loc[:train.shape[0],c].unique())
    testno = len(x.loc[train.shape[0]:,c].unique())
    print(c,trainno,testno)
# Out:
# J_F1_OTHER_LON_6M_AVBL_AM_RE 3 3
# J_F1_OTHER_LON_MAX_3M_AM_RE 4 4
# J_SHINBO_GIBO_AM_RE 2 2
# J_TOT_LON_CNT_RE 4 4
# J_TOT_LON_AGG_AM_RE 4 4
# J_TOT_LON_MAX_AM_RE 4 4
# J_DPS_CT_BAL_AM_RE 3 3
# J_TOT_DPS_1M_AVBL_AM_RE 3 3
# J_TOT_DPS_6M_AVBL_AM_RE 3 3
# J_CORE_DPS_1M_AVBL_AM_RE 3 3
# J_CORE_DPS_6M_AVBL_AM_RE 3 3
# J_TOT_DPS_ACC_CNT_RE 3 3
# J_NRML_DPS_ACC_CNT_RE 3 3
# J_TOT_SAVING_ACC_CNT_RE 3 3
# J_NRML_SAVING_ACC_CNT_RE 3 3
# J_TOT_TS_1M_CNT_RE 3 3
# J_TOT_TS_6M_CNT_RE 3 3
# J_TOT_TS_1M_AM_RE 3 3
# J_TOT_TS_6M_AM_RE 3 3
# J_OB_TS_1M_CNT_RE 3 3
# J_OB_TS_6M_CNT_RE 3 3
# J_OB_TS_1M_AM_RE 3 3
# J_OB_TS_6M_AM_RE 4 4
# J_IB_TS_1M_CNT_RE 3 3
# J_IB_TS_6M_CNT_RE 3 3
# J_IB_TS_1M_AM_RE 3 3
# J_IB_TS_6M_AM_RE 3 3
# J_TOT_TS_3M_AVG_CNT_RE 3 3
# J_TOT_TS_6M_AVG_CNT_RE 3 3
# J_TOT_TS_3M_AVG_AM_RE 3 3
# J_TOT_TS_6M_AVG_AM_RE 3 3
# J_OB_TS_3M_AVG_CNT_RE 4 4
# J_OB_TS_6M_AVG_CNT_RE 4 4
# J_OB_TS_3M_AVG_AM_RE 3 3
# J_OB_TS_6M_AVG_AM_RE 3 3
# J_IB_TS_3M_AVG_CNT_RE 3 3
# J_IB_TS_6M_AVG_CNT_RE 3 3
# J_IB_TS_3M_AVG_AM_RE 3 3
# J_IB_TS_6M_AVG_AM_RE 3 3
# OBK_GRCR_AM_RE 3 3
# M6L_OBK_GRCR_AM_RE 4 4
# J_SIC_CD_5_RE 2 2
# J_SKIL_GDCD_RE 2 2
# J_MAIN_LON_BANK_CD_RE 2 2
# J_CTM_ASET_TOT_AM_RE 4 4
# J_LBLT_TOT_AM_RE 4 4
# J_TOT_BRW_AM_RE 4 4
# J_CTM_CPTS_TOT_AM_RE 4 4
# J_CTM_SAL_AM_RE 4 4
# J_SAL_PCS_AM_RE 4 4
# J_BZ_PFT_AM_RE 4 4
# J_FNC_COST_AM_RE 4 4
# J_CTM_NPFT_AM_RE 4 4
# J_BZ_AFACT_CSFL_AM_RE 2 2
# J_PFPC_CPMT_AF_CSFL_AM_RE 2 2
# J_EBIT_VAL_NV_RT_RE 4 4
# J_EBITDA_VAL_NV_RT_RE 3 3
# J_LBLT_RT_RE 4 4
# J_FNC_COST_CMP_SALEM_RT_RE 3 3
# J_BRWM_DPIN_RT_RE 4 4
# J_STM_BRWM_DPIN_RT_RE 3 3
# J_SALEM_BZ_PFT_RT_RE 3 3
# P_PRIMARY_CUSTOM_FLG_RE 2 2
# P_ACT_CUSTOM_FLG_RE 2 2
# P_TOT_LON_FLG_RE 2 2
# P_INBK_JNNG_FLG_RE 2 2
# P_SMPB_JNNG_FLG_RE 2 2
# P_TOT_DPS_1M_AVBL_AM_RE 4 4
# P_TOT_DPS_6M_AVBL_AM_RE 3 3
# P_CORE_DPS_1M_AVBL_AM_RE 3 3
# P_CORE_DPS_6M_AVBL_AM_RE 4 4
# P_TOT_DPS_ACC_CNT_RE 3 3
# P_NRML_DPS_ACC_CNT_RE 3 3
# P_NRML_SAVING_ACC_CNT_RE 3 3
# P_TOT_SAVING_ACC_CNT_RE 3 3
# P_MAX_TRN_1M_AM_RE 3 3
# P_MAX_TRN_6M_AM_RE 3 3
# P_AVG_TRN_1M_AM_RE 3 3
# P_AVG_TRN_6M_AM_RE 4 4
# P_SUM_TRN_1M_AM_RE 3 3
# P_SUM_TRN_6M_AM_RE 3 3
# P_BR_CNTC_1M_CNT_RE 3 3
# P_BR_CNTC_6M_CNT_RE 3 3
# P_ATM_CNTC_6M_CNT_RE 3 3
# P_INT_CNTC_6M_CNT_RE 2 2
# P_TOT_LON_CNT_RE 3 3
# P_TOT_LON_AGG_AM_RE 3 3
# P_TOT_TS_6M_CNT_RE 3 3
# P_TOT_TS_6M_AM_RE 3 3
# P_OB_TS_6M_CNT_RE 3 3
# P_OB_TS_6M_AM_RE 3 3
# Unnamed: 0 2 35861

# %%
x.loc[:,'J_SIC_CD_5_RE'] = pd.cut(x['J_SIC_CD_5_RE'], 50,labels=False)
x.loc[:,'J_SKIL_GDCD_RE'] = pd.cut(x['J_SKIL_GDCD_RE'], 50,labels=False)
x.loc[:,'J_MAIN_LON_BANK_CD_RE'] = pd.cut(x['J_MAIN_LON_BANK_CD_RE'], 50,labels=False)
x.loc[:,'P_PRIMARY_CUSTOM_FLG_RE'] =  pd.cut(x['P_PRIMARY_CUSTOM_FLG_RE'], 50,labels=False)
x.loc[:,'P_ACT_CUSTOM_FLG_RE'] =  pd.cut(x['P_ACT_CUSTOM_FLG_RE'], 50,labels=False)
x.loc[:,'P_TOT_LON_FLG_RE'] =  pd.cut(x['P_TOT_LON_FLG_RE'], 50,labels=False)
x.loc[:,'P_INBK_JNNG_FLG_RE'] =  pd.cut(x['P_INBK_JNNG_FLG_RE'], 50,labels=False)
x.loc[:,'P_SMPB_JNNG_FLG_RE'] =  pd.cut(x['P_SMPB_JNNG_FLG_RE'], 50,labels=False)

# %%
test = x.loc[train.shape[0]:].copy()
train = x.loc[:train.shape[0]].copy()

# %%
#Always good to shuffle for SGD type optimizers
train = train.sample(frac=1).reset_index(drop=True)

# %%
train.drop('Unnamed: 0',inplace=True,axis=1)
test.drop('Unnamed: 0',inplace=True,axis=1)

# %%
train.head()
# Out:
#    TARGET  J_F1_LON_RK_3M_CNT_RE  J_F1_OTHER_LON_6M_AVBL_AM_RE  \
# 0       0                      1                             2
# 1       1                      3                             3
# 2       1                      2                             3
# 3       0                      1                             1
# 4       1                      3                             3
#
#    J_F1_OTHER_LON_MAX_3M_AM_RE  J_SHINBO_GIBO_AM_RE  J_TOT_LON_CNT_RE  \
# 0                            2                    1                 1
# 1                            3                    2                 1
# 2                            3                    1                 1
# 3                            2                    1                 1
# 4                            4                    1                 4
#
#    J_TOT_LON_AGG_AM_RE  J_TOT_LON_MAX_AM_RE  J_DPS_CT_BAL_AM_RE  \
# 0                    1                    1                   1
# 1                    1                    1                   1
# 2                    1                    1                   1
# 3                    1                    1                   1
# 4                    4                    4                   3
#
#    J_TOT_DPS_1M_AVBL_AM_RE  ...  P_BR_CNTC_1M_CNT_RE  P_BR_CNTC_6M_CNT_RE  \
# 0                        1  ...                    1                    1
# 1                        1  ...                    2                    2
# 2                        1  ...                    1                    1
# 3                        1  ...                    1                    1
# 4                        3  ...                    1                    3
#
#    P_ATM_CNTC_6M_CNT_RE  P_INT_CNTC_6M_CNT_RE  P_TOT_LON_CNT_RE  \
# 0                     1                     2                 3
# 1                     1                     1                 1
# 2                     1                     1                 1
# 3                     1                     1                 2
# 4                     1                     2                 3
#
#    P_TOT_LON_AGG_AM_RE  P_TOT_TS_6M_CNT_RE  P_TOT_TS_6M_AM_RE  \
# 0                    2                   2                  2
# 1                    1                   1                  1
# 2                    1                   1                  1
# 3                    2                   1                  1
# 4                    3                   2                  3
#
#    P_OB_TS_6M_CNT_RE  P_OB_TS_6M_AM_RE
# 0                  2                 2
# 1                  1                 1
# 2                  1                 1
# 3                  1                 1
# 4                  2                 3
#
# [5 rows x 93 columns]

# %%
test.head()
# Out:
#         TARGET  J_F1_LON_RK_3M_CNT_RE  J_F1_OTHER_LON_6M_AVBL_AM_RE  \
# 166224       0                      2                             1
# 166225       0                      1                             2
# 166226       0                      1                             2
# 166227       0                      2                             1
# 166228       0                      1                             1
#
#         J_F1_OTHER_LON_MAX_3M_AM_RE  J_SHINBO_GIBO_AM_RE  J_TOT_LON_CNT_RE  \
# 166224                            1                    1                 3
# 166225                            3                    1                 1
# 166226                            3                    1                 1
# 166227                            1                    1                 1
# 166228                            1                    1                 1
#
#         J_TOT_LON_AGG_AM_RE  J_TOT_LON_MAX_AM_RE  J_DPS_CT_BAL_AM_RE  \
# 166224                    2                    2                   1
# 166225                    1                    1                   1
# 166226                    1                    1                   3
# 166227                    1                    1                   1
# 166228                    1                    1                   1
#
#         J_TOT_DPS_1M_AVBL_AM_RE  ...  P_BR_CNTC_1M_CNT_RE  \
# 166224                        1  ...                    1
# 166225                        1  ...                    3
# 166226                        3  ...                    1
# 166227                        1  ...                    1
# 166228                        1  ...                    1
#
#         P_BR_CNTC_6M_CNT_RE  P_ATM_CNTC_6M_CNT_RE  P_INT_CNTC_6M_CNT_RE  \
# 166224                    1                     1                     1
# 166225                    3                     3                     2
# 166226                    1                     1                     1
# 166227                    1                     1                     1
# 166228                    1                     3                     2
#
#         P_TOT_LON_CNT_RE  P_TOT_LON_AGG_AM_RE  P_TOT_TS_6M_CNT_RE  \
# 166224                 1                    1                   1
# 166225                 3                    3                   3
# 166226                 1                    1                   1
# 166227                 1                    1                   1
# 166228                 1                    1                   1
#
#         P_TOT_TS_6M_AM_RE  P_OB_TS_6M_CNT_RE  P_OB_TS_6M_AM_RE
# 166224                  1                  1                 1
# 166225                  3                  3                 3
# 166226                  1                  1                 1
# 166227                  1                  1                 1
# 166228                  1                  1                 1
#
# [5 rows x 93 columns]

# %%
categories = train.columns[1:]
numerics = []

# %%
currentcode = len(numerics)
catdict = {}
catcodes = {}
for x in numerics:
    catdict[x] = 0
for x in categories:
    catdict[x] = 1

noofrows = train.shape[0]
noofcolumns = len(features)
with open("alltrainffm.txt", "w") as text_file:
    for n, r in enumerate(range(noofrows)):
        if((n%100000)==0):
            print('Row',n)
        datastring = ""
        datarow = train.iloc[r].to_dict()
        datastring += str(int(datarow['TARGET']))


        for i, x in enumerate(catdict.keys()):
            if(catdict[x]==0):
                datastring = datastring + " "+str(i)+":"+ str(i)+":"+ str(datarow[x])
            else:
                if(x not in catcodes):
                    catcodes[x] = {}
                    currentcode +=1
                    catcodes[x][datarow[x]] = currentcode
                elif(datarow[x] not in catcodes[x]):
                    currentcode +=1
                    catcodes[x][datarow[x]] = currentcode

                code = catcodes[x][datarow[x]]
                datastring = datastring + " "+str(i)+":"+ str(int(code))+":1"
        datastring += '\n'
        text_file.write(datastring)
        
noofrows = test.shape[0]
noofcolumns = len(features)
with open("alltestffm.txt", "w") as text_file:
    for n, r in enumerate(range(noofrows)):
        if((n%100000)==0):
            print('Row',n)
        datastring = ""
        datarow = test.iloc[r].to_dict()
        datastring += str(int(datarow['TARGET']))


        for i, x in enumerate(catdict.keys()):
            if(catdict[x]==0):
                datastring = datastring + " "+str(i)+":"+ str(i)+":"+ str(datarow[x])
            else:
                if(x not in catcodes):
                    catcodes[x] = {}
                    currentcode +=1
                    catcodes[x][datarow[x]] = currentcode
                elif(datarow[x] not in catcodes[x]):
                    currentcode +=1
                    catcodes[x][datarow[x]] = currentcode

                code = catcodes[x][datarow[x]]
                datastring = datastring + " "+str(i)+":"+ str(int(code))+":1"
        datastring += '\n'
        text_file.write(datastring)
# Out:
# Row 0
# Row 100000
# Row 0

# %%
import xlearn as xl

# Training task
ffm_model = xl.create_ffm()                # Use field-aware factorization machine (ffm)
ffm_model.setTrain("./alltrainffm.txt")    # Set the path of training dataset
ffm_model.setValidate("./alltestffm.txt")  # Set the path of validation dataset

# Parameters:
#  0. task: binary classification
#  1. learning rate: 0.2
#  2. regular lambda: 0.002
#  3. evaluation metric: accuracy
param = {'task':'binary', 'lr':0.2, 'lambda':0.002, 'metric':'acc'}

# Start to train
# The trained model will be stored in model.out
ffm_model.fit(param, './model.out')

# Prediction task
ffm_model.setTest("./alltestffm.txt")  # Set the path of test dataset
ffm_model.setSigmoid()                 # Convert output to 0-1

# Start to predict
# The output result will be stored in output.txt
Y_pred1 = ffm_model.predict("./model.out", "./output.txt")

# %%
#성능 평가
from sklearn import metrics
ffm_smote_accuracy=metrics.accuracy_score(test['TARGET'],Y_pred1)
ffm_smote_score=metrics.precision_recall_fscore_support(test['TARGET'],Y_pred1)

print(ffm_smote_accuracy)
print(pd.DataFrame(ffm_smote_score))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-d6ff3ef2e0f9> in <module>
#       1 #성능 평가
#       2 from sklearn import metrics
# ----> 3 ffm_smote_accuracy=metrics.accuracy_score(test['TARGET'],Y_pred1)
#       4 ffm_smote_score=metrics.precision_recall_fscore_support(test['TARGET'],Y_pred1)
#       5
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     200
#     201     # Compute accuracy for each possible representation
# --> 202     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     203     check_consistent_length(y_true, y_pred, sample_weight)
#     204     if y_type.startswith('multilabel'):
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      83     check_consistent_length(y_true, y_pred)
#      84     type_true = type_of_target(y_true)
# ---> 85     type_pred = type_of_target(y_pred)
#      86
#      87     y_type = {type_true, type_pred}
#
# ~\anaconda3\lib\site-packages\sklearn\utils\multiclass.py in type_of_target(y)
#     252
#     253     if not valid:
# --> 254         raise ValueError('Expected array-like (array or non-string sequence), '
#     255                          'got %r' % y)
#     256
#
# ValueError: Expected array-like (array or non-string sequence), got None
